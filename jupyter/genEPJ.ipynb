# %%
cd ../..
# Out:
# /home/sb/school_phd/research/coding/eplus_epJSON

# %%
# %run TEST_genEPJ.py
# Out:
# Sucessfully Loaded Feature Data
# Using Features Dictionary: {'use_humid_cap': 1.0, 'use_therm_mass': 1.0, 'use_win7': 0.0, 'use_condfd': 0.0, 'use_daylight': 1.0, 'pv_model': 1.0, 'pv_couple': 0.0, 'grnd_bc': 1.0, 'enforce_ashrae62': 1.0, 'timestep': 4.0, 'solardistribution': 1.0, 'meter2db': 1.0, 'use_hourly_PEF': 0.0}
#
# __________________________________________________
#     You are using...
#                   _____ ____     _
#   __ _  ___ _ __ | ____|  _ \   | |
#  / _` |/ _ \ '_ \|  _| | |_) |  | |  Version 1.0
# | (_| |  __/ | | | |___|  __/ |_| |     WITH
#  \__, |\___|_| |_|_____|_|   \___/   EnergyPlus 9.0.1
#  |___/
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#
#
# File "data_temp/RefBldgSmallOfficeNew2004_Chicago_prep.idf" will be created
# Data is a File: Opening and processing to type String
# **Executing function: swap_IDFJSON with args: {}**
# **swap_IDFJSON: Given format '<class 'list'>'
# **Writing IDF data for translation with len: 451
# ...

# %%
config
